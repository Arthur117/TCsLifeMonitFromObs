# %% [markdown]
# ## Get additional EarthCARE products
#
# Configure everything in config.toml, in particular my credentials
#
# Note that the script is outputing a lot of information in stdout, because it's designed to be run e.g in VSCode (i.e note with a notebook). I had to customize the oads_download.py script to prevent outputing too much information

# %%
# https://earthcarehandbook.earth.esa.int/catalogue/index

# %%
# General
import os
import glob
import subprocess
import pickle
from tqdm.notebook import tqdm

# %%
PTHS = {
    # 'sar_pth': '/home/arthur/results/sar_extended/05_addPRIMED/dsg.nc',
    'ear_dir': '/home/arthur/results/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/01_COLLOCATE_EARTHCARE_TCs/AC__TC__2B/',
    # 'sav_dir': '/home/arthur/results/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/02_EARTHCARE_DIAGNOSTIC/'
}

# Open EarthCARE
all_data = glob.glob(PTHS['ear_dir'] + '*.nc')
all_data.sort()

# %%
# ### Eventually save the list of files as list of EC overpasses

# list_of_overpasses = [os.path.basename(file).split('.')[0].split('_')[-1] for file in all_data]

# # To save the list of frames
# filename           = PTHS['ear_dir'] + 'list_of_overpasses.pkl'
# with open(filename, 'wb') as file:  # 'wb' pour écriture binaire
#     pickle.dump(list_of_overpasses, file)

# %%
# # Or, to load it
# filename = '/home/arthur/results/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/02_EARTHCARE_DIAGNOSTIC/' + 'list_of_overpasses.pkl'
# with open(filename, 'rb') as file:  # 'rb' pour lecture binaire
#     oaf_values = pickle.load(file)

# %%
oaf_values = ['01708B', '02089A', '02089B', '02618E', '02691A', '02698E', '03958E', '04237E', '04237F', '04290A']

# %%
# # Test
# all_data = ['/home/arthur/results/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/01_COLLOCATE_EARTHCARE_TCs/AC__TC__2B/ECA_EXAA_AC__TC__2B_20240915T172841Z_20240915T232259Z_01708B.nc']

# %%
# oaf_values

# %%
# Try this
# In brief, I need to apply the script oads_download.py to each overpass, and for each requested product.

for oaf in tqdm(oaf_values):
    cmd = ["python", "oads_download.py", "ACMCAP", "-oaf", oaf]
    print(f"Running command: {' '.join(cmd)}")
    subprocess.run(cmd)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Running command: python oads_download.py ACMCAP -oaf 01708B
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=B, orbits=[1708]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20240915T172841Z_20240915T232559Z_01708B
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20240915T172841Z_20240915T232559Z_01708B
#  [1/1]  73% [#####################---------] 00:00:03 - 3.77 MB/s - 38.75/52.92 MB
#  [1/1] Download completed (00:00:13 - 3.77 MB/s - 38.75/52.92 MB)
#  [1/1] Extracting...
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/09/15/ECA_EXAA_ACM_CAP_2B_20240915T172841Z_20240915T232559Z_01708B>)
# Running command: python oads_download.py ACMCAP -oaf 02089A
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:19
# Files downloaded: 1 (52.92 MB at ~3.77 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=A, orbits=[2089]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20241010T045647Z_20241010T105000Z_02089A
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20241010T045647Z_20241010T105000Z_02089A
#  [1/1]  85% [#########################-----] 00:00:05 - 1.32 MB/s - 40.50/47.32 MB-------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB [1/1]  45% [#############-----------------] 00:00:18 - 1.39 MB/s - 21.50/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB62% [##################------------] 00:00:12 - 1.45 MB/s - 29.75/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB [1/1]  45% [#############-----------------] 00:00:18 - 1.39 MB/s - 21.50/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB [1/1]  71% [#####################---------] 00:00:10 - 1.33 MB/s - 34.00/47.32 MB-------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB [1/1]  45% [#############-----------------] 00:00:18 - 1.39 MB/s - 21.50/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB62% [##################------------] 00:00:12 - 1.45 MB/s - 29.75/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB [1/1]  45% [#############-----------------] 00:00:18 - 1.39 MB/s - 21.50/47.32 MB######---------------------] 00:00:21 - 1.50 MB/s - 15.50/47.32 MB
#  [1/1] Download completed (00:00:34 - 1.32 MB/s - 40.50/47.32 MB)
#  [1/1] Extracting...
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/10/10/ECA_EXAA_ACM_CAP_2B_20241010T045647Z_20241010T105000Z_02089A>)
# Running command: python oads_download.py ACMCAP -oaf 02089B
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:40
# Files downloaded: 1 (47.32 MB at ~1.32 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=B, orbits=[2089]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20241010T050822Z_20241010T104924Z_02089B
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20241010T050822Z_20241010T104924Z_02089B
#  [1/1]  88% [##########################----] 00:00:02 - 3.51 MB/s - 53.00/60.19 MB##############-------------] 00:00:06 - 3.57 MB/s - 36.00/60.19 MB
#  [1/1] Download completed (00:00:17 - 3.51 MB/s - 53.00/60.19 MB)
#  [1/1] Extracting...
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/10/10/ECA_EXAA_ACM_CAP_2B_20241010T050822Z_20241010T104924Z_02089B>)
# Running command: python oads_download.py ACMCAP -oaf 02618E
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:23
# Files downloaded: 1 (60.19 MB at ~3.51 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=E, orbits=[2618]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20241113T053855Z_20241113T085650Z_02618E
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20241113T053855Z_20241113T085650Z_02618E
#  [1/1]  92% [###########################---] 00:00:01 - 3.63 MB/s - 54.75/59.29 MB###############------------] 00:00:06 - 3.69 MB/s - 37.00/59.29 MB
#  [1/1] Download completed (00:00:16 - 3.63 MB/s - 54.75/59.29 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/11/13/ECA_EXAA_ACM_CAP_2B_20241113T053855Z_20241113T085650Z_02618E>)
#  [1/1] Extracting...
#
# Running command: python oads_download.py ACMCAP -oaf 02691A
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:21
# Files downloaded: 1 (59.29 MB at ~3.63 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=A, orbits=[2691]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20241117T212924Z_20241117T225659Z_02691A
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20241117T212924Z_20241117T225659Z_02691A
#  [1/1]  86% [##########################----] 00:00:04 - 2.06 MB/s - 62.25/71.67 MB###############------------] 00:00:13 - 2.15 MB/s - 43.25/71.67 MB
#  [1/1] Download completed (00:00:35 - 2.06 MB/s - 62.25/71.67 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/11/17/ECA_EXAA_ACM_CAP_2B_20241117T212924Z_20241117T225659Z_02691A>)
#  [1/1] Extracting...
#
# Running command: python oads_download.py ACMCAP -oaf 02698E
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:41
# Files downloaded: 1 (71.67 MB at ~2.06 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=E, orbits=[2698]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAA_ACM_CAP_2B_20241118T090328Z_20241118T103744Z_02698E
# *[1/1] Starting: ECA_EXAA_ACM_CAP_2B_20241118T090328Z_20241118T103744Z_02698E
#  [1/1]  92% [###########################---] 00:00:02 - 2.32 MB/s - 69.75/75.68 MB##################---------] 00:00:08 - 2.64 MB/s - 53.00/75.68 MB
#  [1/1] Download completed (00:00:32 - 2.32 MB/s - 69.75/75.68 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2024/11/18/ECA_EXAA_ACM_CAP_2B_20241118T090328Z_20241118T103744Z_02698E>)
#  [1/1] Extracting...
#
# Running command: python oads_download.py ACMCAP -oaf 03958E
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:36
# Files downloaded: 1 (75.68 MB at ~2.32 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=E, orbits=[3958]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAB_ACM_CAP_2B_20250207T082755Z_20250207T100527Z_03958E
# *[1/1] Starting: ECA_EXAB_ACM_CAP_2B_20250207T082755Z_20250207T100527Z_03958E
#  [1/1]  87% [##########################----] 00:00:04 - 1.51 MB/s - 46.00/52.61 MB#################----------] 00:00:10 - 1.74 MB/s - 35.25/52.61 MB
#  [1/1] Download completed (00:00:37 - 1.51 MB/s - 46.00/52.61 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2025/02/07/ECA_EXAB_ACM_CAP_2B_20250207T082755Z_20250207T100527Z_03958E>)
#  [1/1] Extracting...
#
# Running command: python oads_download.py ACMCAP -oaf 04237E
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:43
# Files downloaded: 1 (52.61 MB at ~1.51 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=E, orbits=[4237]
#  [1/1] Files found in collection 'EarthCAREL2Products': 0
#  [1/1] Files found in collection 'EarthCAREL2InstChecked': 0
#  [1/1] Files found in collection 'EarthCAREL2Validated': 0
# No files where found for your request
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# No products matching the request could be found on the server
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:07
# Files downloaded: 0 (0.00 MB at ~0.00 MB/s)
# Files unzipped:   0
# Running command: python oads_download.py ACMCAP -oaf 04237F
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=F, orbits=[4237]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAB_ACM_CAP_2B_20250225T065909Z_20250225T090642Z_04237F
# *[1/1] Starting: ECA_EXAB_ACM_CAP_2B_20250225T065909Z_20250225T090642Z_04237F
#  [1/1]  56% [################--------------] 00:00:07 - 2.80 MB/s - 28.25/50.35 MB
#  [1/1] Download completed (00:00:17 - 2.80 MB/s - 28.25/50.35 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2025/02/25/ECA_EXAB_ACM_CAP_2B_20250225T065909Z_20250225T090642Z_04237F>)
#  [1/1] Extracting...
#
# Running command: python oads_download.py ACMCAP -oaf 04290A
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:23
# Files downloaded: 1 (50.35 MB at ~2.80 MB/s)
# Files unzipped:   1
# #============================================================#
# #          EARTHCARE OADS DOWNLOAD SCRIPT (v3.0.0)           #
# #============================================================#
# +------------------------------------------------------------+
# | PART 1 - Search products                                   |
# +------------------------------------------------------------+
# Setting path_to_config to </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Found config file at </home/arthur/scripts/TCsLifeMonitFromObs/PRJCT_VERTICAL_WIND/config.toml>
# Number of pending search requests: 1
# *[1/1] Search request: ACM_CAP_2B, frame=A, orbits=[4290]
#  [1/1] Files found in collection 'EarthCAREL2Products': 1
# List of files found (total number 1):
# Note: To export this list use the option --export_results
# Note: To select only one specific file use the option -i/--select_file_at_index
# +------------------------------------------------------------+
# | PART 2 - Download products                                 |
# +------------------------------------------------------------+
# Selecting dissemination service: ec-pdgs-dissemination2.eo.esa.int
#  [1]  ECA_EXAB_ACM_CAP_2B_20250228T154622Z_20250228T212630Z_04290A
# *[1/1] Starting: ECA_EXAB_ACM_CAP_2B_20250228T154622Z_20250228T212630Z_04290A
#  [1/1]  52% [###############---------------] 00:00:09 - 3.92 MB/s - 39.25/75.01 MB
#  [1/1] Download completed (00:00:18 - 3.92 MB/s - 39.25/75.01 MB)
#  [1/1] File extracted and ZIP-file deleted. (see </home/arthur/data/tropical_cyclones/earthcare/L2b/ACM_CAP_2B/2025/02/28/ECA_EXAB_ACM_CAP_2B_20250228T154622Z_20250228T212630Z_04290A>)
#  [1/1] Extracting...
# +------------------------------------------------------------+
# | END OF SCRIPT                                              |
# +------------------------------------------------------------+
# Execution time:   0 days 00:00:24
# Files downloaded: 1 (75.01 MB at ~3.92 MB/s)
# Files unzipped:   1
